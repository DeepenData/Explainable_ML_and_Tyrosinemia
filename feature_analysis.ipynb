# %%
import pickle
with open('pilot_studies.pickle', 'rb') as handle:
    studies = pickle.load(handle)      # Saca la cosa
studies[0].trials.__len__()

study = studies[0]

# %%
import pandas as pd
from optuna.visualization._pareto_front import _get_pareto_front_info
from typing import Tuple
import optuna
import plotly.graph_objects as go

class TwoObjectiveSolutions:
    """
    A class that provides functionality for handling two-objective solutions in an Optuna study.

    Attributes:
    study (optuna.study.study.Study): The Optuna study object.
    df (pd.DataFrame): DataFrame containing all solutions.
    df_filtered (pd.DataFrame): DataFrame containing solutions that pass the provided cutoffs.
    filtered_trials (List[optuna.trial.FrozenTrial]): Trials that pass the provided cutoffs.
    """

    def __init__(self, study: optuna.study.study.Study, auc_cutoff: float = None, s_cutoff: float = None):
        """
        Initialize the TwoObjectiveSolutions object with an Optuna study.

        Args:
        study (optuna.study.study.Study): The Optuna study object.
        """
        self.study = study
        self.df = None
        self.df_filtered = None
        self.filtered_trials = None
        self.auc_cutoff = auc_cutoff
        self.s_cutoff   = s_cutoff

    def generate_dataframes(self):
        """
        Generate the dataframes for all solutions and the solutions that pass the provided cutoffs.

        Args:
        auc_cutoff (float, optional): The AUC cutoff. Defaults to None.
        s_cutoff (float, optional): The S cutoff. Defaults to None.

        Returns:
        self
        """
        info = _get_pareto_front_info(self.study)
        self.df = self._create_trials_dataframe(info.best_trials_with_values + info.non_best_trials_with_values)

        if self.auc_cutoff is not None and self.s_cutoff is not None:
            self.df_filtered = self.df[(self.df["AUC"] > self.auc_cutoff) & (self.df["S"] > self.s_cutoff)]
        else:
            self.df_filtered = None

        return self

    def get_filtered_trials(self):
        """
        Generate and save trials from the study that surpass both AUC and S cutoffs.

        Args:
        auc_cutoff (float): The AUC cutoff. Only trials with AUC greater than this will be returned.
        s_cutoff (float): The S cutoff. Only trials with S greater than this will be returned.

        Returns:
        self
        """
        # if self.df is None or self.df_filtered is None:
        #     self.generate_dataframes(auc_cutoff, s_cutoff)

        all_trials = self.study.get_trials(deepcopy=False)
        self.filtered_trials = []
        self.filtered_trials.extend(
            trial
            for trial in all_trials
            if (trial.values[0] > self.auc_cutoff) & (trial.values[1] > self.s_cutoff)
        )
        # for trial in all_trials:
        #     if any(self.df_filtered["AUC"] == trial.values[0] and self.df_filtered["S"] == trial.values[1]):
        #         self.filtered_trials.append(trial)

        for trial in self.filtered_trials:
            assert trial.values[0] > self.auc_cutoff, f"Trial {trial.number} has AUC ({trial.values[0]}) below the cutoff ({self.auc_cutoff})"
            assert trial.values[1] > self.s_cutoff, f"Trial {trial.number} has S ({trial.values[1]}) below the cutoff ({self.s_cutoff})"

        return self

    def plot_solutions(self):
        """
        Generate a scatter plot of the solutions.

        Args:
        
        auc_cutoff (float, optional): The AUC cutoff. Defaults to None.
        s_cutoff (float, optional): The S cutoff. Defaults to None.

        Returns:
        self
        """
        if self.df is None:
            self.generate_dataframes(self.auc_cutoff, self.s_cutoff)

        fig = go.Figure()
        fig.add_trace(go.Scatter(x=self.df["AUC"], y=self.df["S"], mode='markers'))

        if self.auc_cutoff is not None and self.s_cutoff is not None:
            fig.add_shape(type="rect",
                          x0=self.auc_cutoff, y0=self.s_cutoff,
                          x1=max(self.df["AUC"]), y1=max(self.df["S"]),
                          line=dict(color="LightSeaGreen", width=2),
                          fillcolor="LightSeaGreen", opacity=0.3)

        fig.show()

        return self

    def _create_trials_dataframe(self, trials_with_values: Tuple):
        info = _get_pareto_front_info(self.study)
        auc = [values[info.axis_order[0]] for _, values in trials_with_values]
        s = [values[info.axis_order[1]] for _, values in trials_with_values]
        return pd.DataFrame({"AUC": auc, "S": s})

# %%
TwoObjectiveSolutions(study, auc_cutoff=0.8, s_cutoff=0.2).get_filtered_trials().filtered_trials

# auc_cutoff=0.8
# s_cutoff=0
# all_trials = study.get_trials(deepcopy=False)
# filtered_trials = []
# for trial in all_trials:
#     if (trial.values[0] > auc_cutoff) & (trial.values[1] > s_cutoff):
#         #print(f'{trial.values[0] > auc_cutoff}')
#         filtered_trials.append(trial)
# filtered_trials
# Out:
# [FrozenTrial(number=7, state=TrialState.COMPLETE, values=[0.93, 0.5130441188812256], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 34, 624012), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 37, 474213), params={'max_depth': 2, 'eta': 0.22776031794674534, 'subsample': 0.47870315469168867, 'lambda': 0.3061227934799239, 'alpha': 0.05512292859144319, 'scale_pos_weight': 1.027471180068642, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=7, value=None),
#  FrozenTrial(number=8, state=TrialState.COMPLETE, values=[0.91, 0.20947881042957306], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 36, 997938), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 39, 700464), params={'max_depth': 7, 'eta': 0.29525717137171986, 'subsample': 0.20510912619108423, 'lambda': 0.20186630609325973, 'alpha': 0.21083277176203663, 'scale_pos_weight': 3.997700163353533, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=8, value=None),
#  FrozenTrial(number=9, state=TrialState.COMPLETE, values=[0.8466666666666667, 0.29393813014030457], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 37, 276457), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 40, 635471), params={'max_depth': 10, 'eta': 0.29749070119412613, 'subsample': 0.4849681860582866, 'lambda': 0.07495695181643858, 'alpha': 0.87872132668711, 'scale_pos_weight': 4.9237804379620735, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=9, value=None),
#  FrozenTrial(number=17, state=TrialState.COMPLETE, values=[0.84, 0.9148178696632385], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 39, 792876), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 42, 643616), params={'max_depth': 9, 'eta': 0.36353975941885003, 'subsample': 0.3702489844609904, 'lambda': 0.48584045109721763, 'alpha': 0.12679954080944922, 'scale_pos_weight': 3.1035902821288075, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=17, value=None),
#  FrozenTrial(number=18, state=TrialState.COMPLETE, values=[0.9266666666666666, 0.6038434505462646], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 39, 969206), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 43, 190928), params={'max_depth': 4, 'eta': 0.17851355325618412, 'subsample': 0.26778586820563677, 'lambda': 0.6078202667208493, 'alpha': 0.04505445957566068, 'scale_pos_weight': 2.531009055755496, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=18, value=None),
#  FrozenTrial(number=22, state=TrialState.COMPLETE, values=[0.94, 0.7270303964614868], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 40, 652926), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 43, 557349), params={'max_depth': 6, 'eta': 0.277361289948996, 'subsample': 0.4691833361828246, 'lambda': 0.8398338525598231, 'alpha': 0.9372848902454742, 'scale_pos_weight': 2.4232886959736355, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=22, value=None),
#  FrozenTrial(number=23, state=TrialState.COMPLETE, values=[0.8200000000000001, 0.5918921828269958], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 41, 819596), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 45, 930752), params={'max_depth': 9, 'eta': 0.058320558662869657, 'subsample': 0.46628683777252544, 'lambda': 0.2696441330431113, 'alpha': 0.8732597332219406, 'scale_pos_weight': 1.5591749617798911, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=23, value=None),
#  FrozenTrial(number=24, state=TrialState.COMPLETE, values=[0.88, 0.5736716985702515], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 42, 251286), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 44, 859779), params={'max_depth': 6, 'eta': 0.31454300954473746, 'subsample': 0.4304627769264585, 'lambda': 0.9809148398495229, 'alpha': 0.6831461972203141, 'scale_pos_weight': 3.54038673348812, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=24, value=None),
#  FrozenTrial(number=28, state=TrialState.COMPLETE, values=[0.8233333333333334, 0.29568836092948914], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 43, 204803), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 46, 212356), params={'max_depth': 4, 'eta': 0.2660441712735075, 'subsample': 0.32364996190576656, 'lambda': 0.5757912193071579, 'alpha': 0.3468752530361632, 'scale_pos_weight': 1.7260500827153213, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=28, value=None),
#  FrozenTrial(number=30, state=TrialState.COMPLETE, values=[0.8233333333333334, 0.2070915549993515], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 43, 572536), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 46, 317457), params={'max_depth': 9, 'eta': 0.2936945248148591, 'subsample': 0.36361313661386896, 'lambda': 0.3123705895118899, 'alpha': 0.29908711135009014, 'scale_pos_weight': 3.7761290473141953, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=30, value=None),
#  FrozenTrial(number=32, state=TrialState.COMPLETE, values=[0.8266666666666667, 0.2991347312927246], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 45, 204159), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 47, 623551), params={'max_depth': 3, 'eta': 0.37887126105354624, 'subsample': 0.3200573344642781, 'lambda': 0.06559183061767959, 'alpha': 0.5870459797633146, 'scale_pos_weight': 4.845630883053925, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=32, value=None),
#  FrozenTrial(number=33, state=TrialState.COMPLETE, values=[0.8266666666666667, 0.7395356297492981], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 45, 285077), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 48, 610553), params={'max_depth': 4, 'eta': 0.4251604538402449, 'subsample': 0.19613550208011074, 'lambda': 0.7250059091301211, 'alpha': 0.2542098377080597, 'scale_pos_weight': 2.8929649021057866, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=33, value=None),
#  FrozenTrial(number=34, state=TrialState.COMPLETE, values=[0.8600000000000001, 0.21044592559337616], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 45, 521379), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 48, 213414), params={'max_depth': 5, 'eta': 0.09329175862117726, 'subsample': 0.36492467057000333, 'lambda': 0.6332467117252912, 'alpha': 0.43093583879531616, 'scale_pos_weight': 4.4957215634893295, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=34, value=None),
#  FrozenTrial(number=36, state=TrialState.COMPLETE, values=[0.86, 1.0031872987747192], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 46, 223988), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 49, 18804), params={'max_depth': 10, 'eta': 0.3233815994363899, 'subsample': 0.3724545914692191, 'lambda': 0.8166115505570755, 'alpha': 0.9404884697352127, 'scale_pos_weight': 3.461314648592051, 'kfold_splits': 2}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=36, value=None),
#  FrozenTrial(number=37, state=TrialState.COMPLETE, values=[0.8866666666666667, 0.3273031413555145], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 46, 336681), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 48, 594174), params={'max_depth': 10, 'eta': 0.15088441259599958, 'subsample': 0.3383697916677637, 'lambda': 0.5776032268083756, 'alpha': 0.4778586603307764, 'scale_pos_weight': 4.804457742764688, 'kfold_splits': 2}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=37, value=None),
#  FrozenTrial(number=40, state=TrialState.COMPLETE, values=[0.8833333333333333, 0.366399884223938], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 47, 631692), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 50, 393035), params={'max_depth': 8, 'eta': 0.2857841275097956, 'subsample': 0.283567901269107, 'lambda': 0.3960756477120625, 'alpha': 0.7864675680573463, 'scale_pos_weight': 4.081037180197871, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=40, value=None),
#  FrozenTrial(number=51, state=TrialState.COMPLETE, values=[0.9433333333333334, 1.1987379789352417], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 51, 883850), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 54, 277945), params={'max_depth': 6, 'eta': 0.46451362390940876, 'subsample': 0.385079504893458, 'lambda': 0.18292315508665924, 'alpha': 0.511658159401425, 'scale_pos_weight': 4.836683331172807, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=51, value=None),
#  FrozenTrial(number=52, state=TrialState.COMPLETE, values=[0.8633333333333334, 0.2927524447441101], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 51, 889977), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 57, 108461), params={'max_depth': 6, 'eta': 0.0648929773709709, 'subsample': 0.4425221419913288, 'lambda': 0.8614166625191053, 'alpha': 0.46571455696140707, 'scale_pos_weight': 1.0891739746281248, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=52, value=None),
#  FrozenTrial(number=53, state=TrialState.COMPLETE, values=[0.88, 0.5780019760131836], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 52, 523858), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 55, 311043), params={'max_depth': 7, 'eta': 0.25268065311146315, 'subsample': 0.45916483532273344, 'lambda': 0.5294466024396933, 'alpha': 0.7950903126218015, 'scale_pos_weight': 1.5667008523424424, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=53, value=None),
#  FrozenTrial(number=56, state=TrialState.COMPLETE, values=[0.8733333333333333, 0.31127646565437317], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 53, 501880), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 55, 965441), params={'max_depth': 3, 'eta': 0.23879314262386242, 'subsample': 0.2991435027198174, 'lambda': 0.7804882805393227, 'alpha': 0.29346386044150685, 'scale_pos_weight': 1.599184276608157, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 0}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=56, value=None),
#  FrozenTrial(number=59, state=TrialState.COMPLETE, values=[0.94, 0.5033827424049377], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 54, 780927), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 57, 80942), params={'max_depth': 6, 'eta': 0.29525717137171986, 'subsample': 0.20510912619108423, 'lambda': 0.20186630609325973, 'alpha': 0.9372848902454742, 'scale_pos_weight': 3.997700163353533, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=59, value=None),
#  FrozenTrial(number=60, state=TrialState.COMPLETE, values=[0.85, 0.9677441120147705], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 55, 326779), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 58, 119008), params={'max_depth': 3, 'eta': 0.37887126105354624, 'subsample': 0.3200573344642781, 'lambda': 0.06559183061767959, 'alpha': 0.08963683685925894, 'scale_pos_weight': 2.9220108696832843, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=60, value=None),
#  FrozenTrial(number=61, state=TrialState.COMPLETE, values=[0.9133333333333333, 0.47388899326324463], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 55, 460080), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 57, 786756), params={'max_depth': 6, 'eta': 0.3809180964015979, 'subsample': 0.16168467976557166, 'lambda': 0.6120331313538452, 'alpha': 0.3423964173177665, 'scale_pos_weight': 2.4232886959736355, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=61, value=None),
#  FrozenTrial(number=62, state=TrialState.COMPLETE, values=[0.87, 0.5765909552574158], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 55, 725206), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 58, 352496), params={'max_depth': 7, 'eta': 0.25268065311146315, 'subsample': 0.47870315469168867, 'lambda': 0.3061227934799239, 'alpha': 0.7950903126218015, 'scale_pos_weight': 1.027471180068642, 'kfold_splits': 2}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=62, value=None),
#  FrozenTrial(number=64, state=TrialState.COMPLETE, values=[0.9133333333333333, 1.0739718675613403], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 56, 326226), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 59, 465105), params={'max_depth': 6, 'eta': 0.46451362390940876, 'subsample': 0.385079504893458, 'lambda': 0.18292315508665924, 'alpha': 0.511658159401425, 'scale_pos_weight': 4.836683331172807, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=64, value=None),
#  FrozenTrial(number=66, state=TrialState.COMPLETE, values=[0.8433333333333333, 0.20170433819293976], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 57, 129144), datetime_complete=datetime.datetime(2023, 5, 30, 19, 43, 59, 962298), params={'max_depth': 2, 'eta': 0.21548367715246253, 'subsample': 0.20798600884869725, 'lambda': 0.8823074388175793, 'alpha': 0.05512292859144319, 'scale_pos_weight': 3.7832171385013016, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=66, value=None),
#  FrozenTrial(number=68, state=TrialState.COMPLETE, values=[0.83, 0.5246506929397583], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 57, 807475), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 0, 251936), params={'max_depth': 8, 'eta': 0.22776031794674534, 'subsample': 0.47870315469168867, 'lambda': 0.8262301994242898, 'alpha': 0.03532786543419364, 'scale_pos_weight': 2.639990001484986, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=68, value=None),
#  FrozenTrial(number=69, state=TrialState.COMPLETE, values=[0.97, 0.5465663075447083], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 58, 134625), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 0, 676826), params={'max_depth': 5, 'eta': 0.23879314262386242, 'subsample': 0.4854338628226752, 'lambda': 0.7804882805393227, 'alpha': 0.29346386044150685, 'scale_pos_weight': 2.778987175348355, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=69, value=None),
#  FrozenTrial(number=70, state=TrialState.COMPLETE, values=[0.9133333333333333, 0.3571237027645111], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 58, 361417), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 1, 105693), params={'max_depth': 10, 'eta': 0.38435922297333547, 'subsample': 0.45916483532273344, 'lambda': 0.5294466024396933, 'alpha': 0.7950903126218015, 'scale_pos_weight': 1.5667008523424424, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=70, value=None),
#  FrozenTrial(number=71, state=TrialState.COMPLETE, values=[0.8733333333333333, 0.36636361479759216], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 58, 725905), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 1, 130014), params={'max_depth': 8, 'eta': 0.17851355325618412, 'subsample': 0.26778586820563677, 'lambda': 0.6078202667208493, 'alpha': 0.4188280742785826, 'scale_pos_weight': 4.081037180197871, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=71, value=None),
#  FrozenTrial(number=73, state=TrialState.COMPLETE, values=[0.9000000000000001, 0.5204357504844666], datetime_start=datetime.datetime(2023, 5, 30, 19, 43, 59, 966263), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 2, 25217), params={'max_depth': 8, 'eta': 0.2857841275097956, 'subsample': 0.283567901269107, 'lambda': 0.18022457009174264, 'alpha': 0.7864675680573463, 'scale_pos_weight': 1.6673584083346182, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=73, value=None),
#  FrozenTrial(number=75, state=TrialState.COMPLETE, values=[0.8166666666666668, 0.28854304552078247], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 0, 686942), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 2, 690744), params={'max_depth': 5, 'eta': 0.1919260492480243, 'subsample': 0.47870315469168867, 'lambda': 0.9604930542852876, 'alpha': 0.6490640227607783, 'scale_pos_weight': 0.9510262181667561, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=75, value=None),
#  FrozenTrial(number=76, state=TrialState.COMPLETE, values=[0.91, 0.49367496371269226], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 1, 116459), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 3, 564442), params={'max_depth': 6, 'eta': 0.35056688418987575, 'subsample': 0.33874698149889326, 'lambda': 0.18292315508665924, 'alpha': 0.511658159401425, 'scale_pos_weight': 1.4002260581159232, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=76, value=None),
#  FrozenTrial(number=78, state=TrialState.COMPLETE, values=[0.8733333333333333, 0.36499765515327454], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 2, 29818), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 5, 274290), params={'max_depth': 2, 'eta': 0.2660441712735075, 'subsample': 0.15865668777641517, 'lambda': 0.5757912193071579, 'alpha': 0.7401062047183415, 'scale_pos_weight': 1.7260500827153213, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=78, value=None),
#  FrozenTrial(number=87, state=TrialState.COMPLETE, values=[0.8133333333333334, 0.4662262499332428], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 5, 231282), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 7, 898556), params={'max_depth': 3, 'eta': 0.37887126105354624, 'subsample': 0.3200573344642781, 'lambda': 0.12483937060806694, 'alpha': 0.23444063818188243, 'scale_pos_weight': 4.845630883053925, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=87, value=None),
#  FrozenTrial(number=88, state=TrialState.COMPLETE, values=[0.8366666666666667, 0.4485887587070465], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 5, 281482), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 8, 3096), params={'max_depth': 3, 'eta': 0.203798542322811, 'subsample': 0.4420495042623045, 'lambda': 0.47518649866352425, 'alpha': 0.04505445957566068, 'scale_pos_weight': 2.531009055755496, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=88, value=None),
#  FrozenTrial(number=92, state=TrialState.COMPLETE, values=[0.8133333333333334, 0.7056167125701904], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 6, 631635), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 10, 201225), params={'max_depth': 9, 'eta': 0.18095736102760177, 'subsample': 0.3702489844609904, 'lambda': 0.48584045109721763, 'alpha': 0.5296855819948817, 'scale_pos_weight': 3.9867879910730752, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=92, value=None),
#  FrozenTrial(number=93, state=TrialState.COMPLETE, values=[0.8433333333333334, 0.8719438314437866], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 6, 905951), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 9, 285387), params={'max_depth': 10, 'eta': 0.3233815994363899, 'subsample': 0.3724545914692191, 'lambda': 0.8166115505570755, 'alpha': 0.47145291717571947, 'scale_pos_weight': 3.5803099424657647, 'kfold_splits': 2}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=93, value=None),
#  FrozenTrial(number=99, state=TrialState.COMPLETE, values=[0.8933333333333333, 0.6083179116249084], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 9, 304359), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 11, 781181), params={'max_depth': 9, 'eta': 0.25268065311146315, 'subsample': 0.45916483532273344, 'lambda': 0.5294466024396933, 'alpha': 0.7950903126218015, 'scale_pos_weight': 1.2934355712342305, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=99, value=None),
#  FrozenTrial(number=100, state=TrialState.COMPLETE, values=[0.8250000000000001, 0.2960710823535919], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 10, 204372), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 12, 108738), params={'max_depth': 7, 'eta': 0.3233815994363899, 'subsample': 0.3724545914692191, 'lambda': 0.8166115505570755, 'alpha': 0.9404884697352127, 'scale_pos_weight': 3.461314648592051, 'kfold_splits': 2}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=100, value=None),
#  FrozenTrial(number=105, state=TrialState.COMPLETE, values=[0.8200000000000001, 0.48203030228614807], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 11, 786912), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 14, 358313), params={'max_depth': 2, 'eta': 0.23879314262386242, 'subsample': 0.2991435027198174, 'lambda': 0.7804882805393227, 'alpha': 0.29346386044150685, 'scale_pos_weight': 1.599184276608157, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=105, value=None),
#  FrozenTrial(number=106, state=TrialState.COMPLETE, values=[0.8566666666666667, 0.25205209851264954], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 12, 98713), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 16, 390377), params={'max_depth': 6, 'eta': 0.0648929773709709, 'subsample': 0.19613550208011074, 'lambda': 0.8614166625191053, 'alpha': 0.2542098377080597, 'scale_pos_weight': 1.6471678601642625, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=106, value=None),
#  FrozenTrial(number=107, state=TrialState.COMPLETE, values=[0.9566666666666668, 0.5029942393302917], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 12, 112512), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 14, 489572), params={'max_depth': 4, 'eta': 0.2660441712735075, 'subsample': 0.4593911001749543, 'lambda': 0.4441695999019942, 'alpha': 0.7461136107260727, 'scale_pos_weight': 2.531009055755496, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=107, value=None),
#  FrozenTrial(number=111, state=TrialState.COMPLETE, values=[0.8633333333333334, 0.2168654054403305], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 13, 652413), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 15, 568823), params={'max_depth': 9, 'eta': 0.44704510678926423, 'subsample': 0.18843208658289035, 'lambda': 0.9809148398495229, 'alpha': 0.6831461972203141, 'scale_pos_weight': 3.54038673348812, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=111, value=None),
#  FrozenTrial(number=112, state=TrialState.COMPLETE, values=[0.8999999999999999, 0.3479846715927124], datetime_start=datetime.datetime(2023, 5, 30, 19, 44, 14, 365188), datetime_complete=datetime.datetime(2023, 5, 30, 19, 44, 16, 762300), params={'max_depth': 2, 'eta': 0.37887126105354624, 'subsample': 0.325698007216915, 'lambda': 0.13693248831614135, 'alpha': 0.5870459797633146, 'scale_pos_weight': 4.845630883053925, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 1}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=112, value=None),
# ...
#  FrozenTrial(number=1738, state=TrialState.COMPLETE, values=[0.92, 0.6948859691619873], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 47, 591519), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 50, 706699), params={'max_depth': 9, 'eta': 0.25268065311146315, 'subsample': 0.21701590284656425, 'lambda': 0.2183042189254497, 'alpha': 0.12679954080944922, 'scale_pos_weight': 3.9867879910730752, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1738, value=None),
#  FrozenTrial(number=1739, state=TrialState.COMPLETE, values=[0.8766666666666667, 0.7097492814064026], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 48, 700732), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 51, 239872), params={'max_depth': 6, 'eta': 0.47776797376100705, 'subsample': 0.385079504893458, 'lambda': 0.18292315508665924, 'alpha': 0.511658159401425, 'scale_pos_weight': 4.836683331172807, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1739, value=None),
#  FrozenTrial(number=1741, state=TrialState.COMPLETE, values=[0.9099999999999999, 0.4686679244041443], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 49, 265884), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 53, 78517), params={'max_depth': 6, 'eta': 0.25268065311146315, 'subsample': 0.4593911001749543, 'lambda': 0.2183042189254497, 'alpha': 0.23444063818188243, 'scale_pos_weight': 1.2934355712342305, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1741, value=None),
#  FrozenTrial(number=1744, state=TrialState.COMPLETE, values=[0.9033333333333333, 0.38847360014915466], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 49, 672225), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 52, 809657), params={'max_depth': 4, 'eta': 0.25268065311146315, 'subsample': 0.4744026354631188, 'lambda': 0.20186630609325973, 'alpha': 0.7950903126218015, 'scale_pos_weight': 2.531009055755496, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1744, value=None),
#  FrozenTrial(number=1747, state=TrialState.COMPLETE, values=[0.8666666666666667, 0.5599794983863831], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 51, 250452), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 53, 924437), params={'max_depth': 9, 'eta': 0.37887126105354624, 'subsample': 0.4854338628226752, 'lambda': 0.18022457009174264, 'alpha': 0.2661960840269344, 'scale_pos_weight': 1.2934355712342305, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1747, value=None),
#  FrozenTrial(number=1749, state=TrialState.COMPLETE, values=[0.8066666666666666, 1.1364853382110596], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 51, 973630), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 54, 713412), params={'max_depth': 3, 'eta': 0.44971678525677555, 'subsample': 0.4573573897218005, 'lambda': 0.18022457009174264, 'alpha': 0.12679954080944922, 'scale_pos_weight': 3.8445489924038045, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1749, value=None),
#  FrozenTrial(number=1754, state=TrialState.COMPLETE, values=[0.81, 0.6567806005477905], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 53, 95784), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 56, 528041), params={'max_depth': 8, 'eta': 0.44971678525677555, 'subsample': 0.4253057913776135, 'lambda': 0.18292315508665924, 'alpha': 0.7864675680573463, 'scale_pos_weight': 1.0334314324025402, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1754, value=None),
#  FrozenTrial(number=1755, state=TrialState.COMPLETE, values=[0.86, 0.7490730881690979], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 53, 946290), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 56, 636802), params={'max_depth': 8, 'eta': 0.46451362390940876, 'subsample': 0.385079504893458, 'lambda': 0.18292315508665924, 'alpha': 0.6937811944207661, 'scale_pos_weight': 1.4002260581159232, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1755, value=None),
#  FrozenTrial(number=1757, state=TrialState.COMPLETE, values=[0.9, 0.43059074878692627], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 54, 720278), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 57, 358289), params={'max_depth': 10, 'eta': 0.44971678525677555, 'subsample': 0.4593911001749543, 'lambda': 0.2183042189254497, 'alpha': 0.23444063818188243, 'scale_pos_weight': 1.4002260581159232, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1757, value=None),
#  FrozenTrial(number=1759, state=TrialState.COMPLETE, values=[0.8066666666666665, 0.5363946557044983], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 55, 375595), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 58, 127690), params={'max_depth': 9, 'eta': 0.44971678525677555, 'subsample': 0.3702489844609904, 'lambda': 0.18022457009174264, 'alpha': 0.12679954080944922, 'scale_pos_weight': 1.2934355712342305, 'kfold_splits': 3}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1759, value=None),
#  FrozenTrial(number=1760, state=TrialState.COMPLETE, values=[0.8833333333333333, 0.6135551333427429], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 55, 425972), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 59, 137914), params={'max_depth': 6, 'eta': 0.46451362390940876, 'subsample': 0.3724545914692191, 'lambda': 0.18292315508665924, 'alpha': 0.7864675680573463, 'scale_pos_weight': 1.439114045582099, 'kfold_splits': 5}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1760, value=None),
#  FrozenTrial(number=1761, state=TrialState.COMPLETE, values=[0.89, 0.3859390318393707], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 55, 467065), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 57, 801818), params={'max_depth': 9, 'eta': 0.2959646698957278, 'subsample': 0.3702489844609904, 'lambda': 0.18022457009174264, 'alpha': 0.12679954080944922, 'scale_pos_weight': 2.6639853327336764, 'kfold_splits': 2}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1761, value=None),
#  FrozenTrial(number=1762, state=TrialState.COMPLETE, values=[0.8366666666666667, 0.2122878134250641], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 56, 541525), datetime_complete=datetime.datetime(2023, 5, 30, 19, 53, 59, 627829), params={'max_depth': 9, 'eta': 0.21505068171439448, 'subsample': 0.481535555144301, 'lambda': 0.2183042189254497, 'alpha': 0.7864675680573463, 'scale_pos_weight': 2.518414596375513, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1762, value=None),
#  FrozenTrial(number=1764, state=TrialState.COMPLETE, values=[0.87, 0.6218596696853638], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 57, 292959), datetime_complete=datetime.datetime(2023, 5, 30, 19, 54, 0, 492723), params={'max_depth': 4, 'eta': 0.48799159790728563, 'subsample': 0.481535555144301, 'lambda': 0.6609617020327081, 'alpha': 0.23444063818188243, 'scale_pos_weight': 2.531009055755496, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 30}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1764, value=None),
#  FrozenTrial(number=1765, state=TrialState.COMPLETE, values=[0.9400000000000001, 0.5068511962890625], datetime_start=datetime.datetime(2023, 5, 30, 19, 53, 57, 371891), datetime_complete=datetime.datetime(2023, 5, 30, 19, 54, 0, 221270), params={'max_depth': 5, 'eta': 0.35056688418987575, 'subsample': 0.481535555144301, 'lambda': 0.18022457009174264, 'alpha': 0.23444063818188243, 'scale_pos_weight': 2.6757570469744927, 'kfold_splits': 4}, user_attrs={}, system_attrs={'nsga2:generation': 31}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=2, step=1), 'eta': FloatDistribution(high=0.5, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'lambda': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'alpha': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'scale_pos_weight': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'kfold_splits': IntDistribution(high=5, log=False, low=2, step=1)}, trial_id=1765, value=None),
#  ...]
